# %% [markdown]
#   ## STUDENT NAME :- Nikhil Shivaji Mali
#   ## DIV:- B
#   ## PEACTICAL BATCH:- B-1
#   ## ROLL NO:- 03
#   ## DATE:- 23/09/2026
#   ## PRACTICAL NO:- 03
#   ## PRACTICAL NAME:- IMPLEMENT A TOY CLASSIFICATION PROBLEM USING DECISION BOUNDARIES

# %% [markdown]
# ## Practical No. 3: Implement a Toy Classification Problem Using Decision Boundaries
#
# **Good morning sir. My practical is Practical No. 3, “Implement a Toy Classification Problem Using Decision Boundaries.”**
#
# The main objective of this practical is to use a machine learning classification algorithm to classify Iris flowers into different species based on their measurements.
#
# ### 1. Import Libraries
#
# First, I imported the required libraries.
#
# `NumPy` is used for numerical operations, `Pandas` is used for handling data in table form, and `Matplotlib` is used for visualization.
#
# I also imported the `Iris` dataset from Scikit-learn.
#
# ### 2. Data Collection
#
# I loaded the Iris dataset using:
#
# `load_iris()`
#
# The Iris dataset contains flower measurements such as:
#
# * Sepal Length
# * Sepal Width
# * Petal Length
# * Petal Width
#
# There are three target classes:
#
# **0 = Setosa, 1 = Versicolor, 2 = Virginica.**
#
# I converted the dataset into a Pandas DataFrame and added the target column as `Species`.
#
# Then I used `head()` to display the first five records.
#
# ### 3. Data Collection and EDA
#
# After collecting the data, I performed Exploratory Data Analysis, or EDA.
#
# EDA means understanding and analyzing the dataset before building the model.
#
# First, I used:
#
# `data.shape`
#
# to check the number of rows and columns.
#
# Then I used:
#
# `data.info()`
#
# to understand the structure of the dataset, such as column names and data types.
#
# After that, I used:
#
# `value_counts()`
#
# to check how many samples belong to each species.
#
# ### 4. Data Visualization
#
# I created a scatter plot using **Petal Length and Petal Width**.
#
# The scatter plot helps us visualize how the different species are distributed and how they can be separated based on their features.
#
# I also created a boxplot.
#
# The boxplot is useful for identifying the distribution of data and possible outliers.
#
# ### 5. Independent and Dependent Variables
#
# Next, I divided the data into independent and dependent variables.
#
# `X` contains the four flower measurements, so **X represents the input features or independent variables**.
#
# `y` contains the Species column, so **y represents the target or dependent variable**.
#
# In simple words:
#
# **X = Input / Features**
#
# **y = Output / Target**
#
# ### 6. Train-Test Split
#
# After that, I divided the dataset into training and testing data using `train_test_split()`.
#
# I used `test_size = 0.2`.
#
# This means **20% of the data is used for testing and the remaining 80% is used for training**.
#
# Training data is used to teach the model, while testing data is used to check how well the model performs on unseen data.
#
# ### 7. Model Building
#
# For classification, I used the **Decision Tree Classifier**.
#
# A Decision Tree works like a series of questions or conditions.
#
# For example, based on petal length, petal width, or other features, the model makes decisions and finally predicts the flower species.
#
# I used:
#
# `max_depth = 3`
#
# which limits the maximum depth of the tree.
#
# I also used `random_state = 42` so that the model's random behavior remains reproducible.
#
# ### 8. Model Training
#
# I trained the Decision Tree using:
#
# `model.fit(X_train, y_train)`
#
# The model learns the relationship between the input flower measurements and their corresponding species from the training data.
#
# ### 9. Prediction
#
# After training, I predicted the species of the test data using:
#
# `model.predict(X_test)`
#
# The predicted results are stored in `y_pred`.
#
# So now we have:
#
# **y_test = actual answers**
#
# **y_pred = model's predicted answers**
#
# We compare both to evaluate the model.
#
# ### 10. Classification Metrics
#
# I used four evaluation metrics.
#
# **Accuracy** tells us the overall percentage of correct predictions.
#
# **Precision** tells us how many of the samples predicted as a particular class were actually correct.
#
# **Recall** tells us how many of the actual samples of a class were correctly identified.
#
# **F1 Score** gives a balance between precision and recall.
#
# Therefore, these metrics help us understand the performance of the classification model.
#
# ### 11. K-Fold Cross Validation
#
# After the train-test evaluation, I used **5-Fold Cross Validation**.
#
# In 5-Fold Cross Validation, the dataset is divided into five parts, called folds.
#
# In every round, four folds are used for training and one fold is used for testing.
#
# This process is repeated five times, so every fold gets a chance to be used as the testing set.
#
# Finally, I calculate the average Accuracy, Precision, Recall and F1 Score of all five folds.
#
# This gives a more reliable evaluation of the model instead of depending only on one train-test split.
#
# ### 12. Conclusion
#
# Therefore, in this practical, I used the Iris dataset to perform a classification problem.
#
# I performed data analysis and visualization, divided the data into training and testing sets, built a Decision Tree Classifier, trained the model, made predictions, evaluated the model using Accuracy, Precision, Recall and F1 Score, and finally used 5-Fold Cross Validation to get average performance results.
#
# **This practical shows how a classification model can learn from flower features and classify new flowers into their respective species.**

# %% [markdown]
# ## 1. IMPORT LIBRARIES

# %%
# Necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

# %%
iris = load_iris() # Iris flower dataset

# Create DataFrame
data = pd.DataFrame(iris.data, columns=iris.feature_names) #Features

# Add target column
data["Species"] = iris.target
print(data.head()) # First 5 records printed
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ## 2. Data Collection And EDA

# %%
data.shape #(rows, columns)
# Out:
# (150, 5)

# %%
data.info() # Structure of Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
# Target class distribution
data['Species'].value_counts() # 0=setosa , 1 = versicolor, 2=virginica
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %%
# Scatter Plot

plt.scatter(data['petal length (cm)'], data['petal width (cm)'], c=data['Species'])

plt.xlabel('petal length')
plt.ylabel('petal width')
plt.title('Petal Length vs Width')
plt.show()

# %%
data.boxplot() #Used for Outliers detection
plt.show()

# %%
# Data Splitting
X=data.iloc[:, :4] #Independent Variables
y=data.iloc[:, -1] #Dependent Variable

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %%
# Data Splitting
from sklearn.model_selection import train_test_split                          # HOLDS VALADATION 
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
X_train.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 17                5.1               3.5                1.4               0.3
# 97                6.2               2.9                4.3               1.3
# 19                5.1               3.8                1.5               0.3
# 18                5.7               3.8                1.7               0.3
# 10                5.4               3.7                1.5               0.2

# %% [markdown]
# ## 3. Model Building

# %% [markdown]
# # Create Decision Tree model
#
# ### from sklearn.tree import DecisionTreeClassifier
#
# ### model = DecisionTreeClassifier(max_depth=3, random_state=42)
# ### model.fit(X_train, y_train) # Train model

# %%
# Predict test data
y_pred = model.predict(X_test)
y_pred[:10]
# Out:
# array([0, 2, 2, 2, 2, 2, 0, 2, 1, 0])

# %%
# Classification Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score    # classification_report

print("Train-Test Split Results")
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average="weighted"))
print("Recall :", recall_score(y_test, y_pred, average="weighted"))
print("F1 Score :", f1_score(y_test, y_pred, average="weighted"))
# Out:
# Train-Test Split Results
# Accuracy : 1.0
# Precision: 1.0
# Recall : 1.0
# F1 Score : 1.0

# %% [markdown]
# ## K-FOLD Cross Validation
# ### Create K Fold
# ### k-1 fold for Training and remaining fold for testing

# %%
#6. 5-Fold Cross Validation
from sklearn.model_selection import cross_validate, KFold

kf = KFold( n_splits=5, shuffle=True, random_state=42)

results = cross_validate( model, X, y, cv=kf,
                          scoring=["accuracy",
                                   "precision_weighted",
                                   "recall_weighted",
                                   "f1_weighted"])

# %%
# Average K-Fold Results
print("\n5-Fold Cross Validation Results:")
print("Accuracy :", np.mean(results["test_accuracy"]))
print("Precision:", np.mean(results["test_precision_weighted"]))
print("Recall :", np.mean(results["test_recall_weighted"]))
print("F1 Score :", np.mean(results["test_f1_weighted"]))
# Out:
# 5-Fold Cross Validation Results:
# Accuracy : 0.9533333333333334
# Precision: 0.9577676767676767
# Recall : 0.9533333333333334
# F1 Score : 0.953277061103148
